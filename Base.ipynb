-- %% [markdown]
-- # [dbo].[ESTADO_REPORTES]

-- %%
USE [REPORTESAPPS]
GO

-- %%
/****** Object:  Table [dbo].[ESTADO_REPORTES]    Script Date: 19/12/2023 1:45:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ESTADO_REPORTES](
	[ID_ESTREPORTE] [int] IDENTITY(1,1) NOT NULL,
	[NOMBRE_ESTREPORTE] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_ESTREPORTE] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ESTADOS]

-- %%
/****** Object:  Table [dbo].[ESTADOS]    Script Date: 19/12/2023 1:45:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ESTADOS](
	[ID_ESTADO] [int] IDENTITY(1,1) NOT NULL,
	[NOMBRE_ESTADO] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_ESTADO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[REPORTES]

-- %%
/****** Object:  Table [dbo].[REPORTES]    Script Date: 19/12/2023 1:45:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[REPORTES](
	[ID_REPORTE] [int] IDENTITY(1,1) NOT NULL,
	[USER_REPORTE] [int] NULL,
	[TIPO_REPORTE] [int] NULL,
	[ESTADO_REPORTE] [int] NULL,
	[OBSERVACION] [nvarchar](500) NULL,
	[FECHA] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_REPORTE] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TIPO_REPORTE]

-- %%
/****** Object:  Table [dbo].[TIPO_REPORTE]    Script Date: 19/12/2023 1:45:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TIPO_REPORTE](
	[ID_TIPO] [int] IDENTITY(1,1) NOT NULL,
	[NOMBRE_TIPO] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_TIPO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USUARIOS]

-- %%
/****** Object:  Table [dbo].[USUARIOS]    Script Date: 19/12/2023 1:45:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USUARIOS](
	[ID_USER] [int] IDENTITY(1,1) NOT NULL,
	[NOMBRE_USER] [nvarchar](255) NULL,
	[CORREO_USER] [nvarchar](255) NULL,
	[PASS_USER] [nvarchar](255) NULL,
	[ESTADO_USER] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_USER] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[CORREO_USER] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__REPORTES__FECHA__47DBAE45]

-- %%
ALTER TABLE [dbo].[REPORTES] ADD  DEFAULT (getdate()) FOR [FECHA]
GO

-- %% [markdown]
-- # [FK__REPORTES__ESTADO__46E78A0C]

-- %%
ALTER TABLE [dbo].[REPORTES]  WITH CHECK ADD FOREIGN KEY([ESTADO_REPORTE])
REFERENCES [dbo].[ESTADO_REPORTES] ([ID_ESTREPORTE])
GO

-- %% [markdown]
-- # [FK__REPORTES__TIPO_R__45F365D3]

-- %%
ALTER TABLE [dbo].[REPORTES]  WITH CHECK ADD FOREIGN KEY([TIPO_REPORTE])
REFERENCES [dbo].[TIPO_REPORTE] ([ID_TIPO])
GO

-- %% [markdown]
-- # [FK__REPORTES__USER_R__44FF419A]

-- %%
ALTER TABLE [dbo].[REPORTES]  WITH CHECK ADD FOREIGN KEY([USER_REPORTE])
REFERENCES [dbo].[REPORTES] ([ID_REPORTE])
GO

-- %% [markdown]
-- # [FK__USUARIOS__ESTADO__3A81B327]

-- %%
ALTER TABLE [dbo].[USUARIOS]  WITH CHECK ADD FOREIGN KEY([ESTADO_USER])
REFERENCES [dbo].[ESTADOS] ([ID_ESTADO])
GO

-- %% [markdown]
-- # [dbo].[sp_buscar_reporte_por_numero]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_buscar_reporte_por_numero]    Script Date: 19/12/2023 1:45:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_buscar_reporte_por_numero]
    @numeroReporte INT
AS
BEGIN
    SELECT * FROM REPORTES WHERE ID_REPORTE = @numeroReporte
END

GO
